# %%
import numpy as np

# %%
numbers = np.array([10,20,30,40,50])
data = np.array((
    [1,2,3],
    [4,5,6]
))
data[1,2]=5
print(data[1,2])
# Out:
# 5

# %%
print(np.zeros(5))
print(np.full(5,7))
# Out:
# [0. 0. 0. 0. 0.]
# [7 7 7 7 7]

# %%
print(np.linspace(0,10,5))
# Out:
# [ 0.   2.5  5.   7.5 10. ]

# %%
print(np.arange(1,10,2))
# Out:
# [1 3 5 7 9]

# %%
print(data.shape)
# Out:
# (2, 3)
